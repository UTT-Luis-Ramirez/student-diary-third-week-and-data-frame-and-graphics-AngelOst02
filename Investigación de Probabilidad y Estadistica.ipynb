# %% [markdown]
# #**Investigación de Probabilidad y Estadística 🌌**
# ##### Esta tarea tiene como fin profundizar en información sobre los Histogramas, diagrama de tallo y hoja y el diagrama de caja. como es habitual, aquí la portada.
# ![GiFYmQDWsAAn11Q (1).jpg](data:image/jpeg;base64,...)
#
# ---
# #**Histogramas**
# ###¿Qué son y para qué sirven?
# Un histograma es un gráfico de barras que representa la distribución de un conjunto de datos agrupados en intervalos o clases. Sirve para visualizar cómo se distribuyen los datos y detectar patrones, como simetría, sesgo o valores atípicos.
# ![image.png](data:image/png;base64,...)
#
# ###Características
# - Las barras son adyacentes (sin espacios).
# - El eje horizontal representa las clases o intervalos.
# - El eje vertical muestra la frecuencia de cada clase.
# - Útil para datos cuantitativos continuos.
#
# ###Cómo se realizan y en qué casos
#
# - Divide los datos en intervalos de igual amplitud.
# - Cuenta cuántos datos caen en cada intervalo.
# - Dibuja barras proporcionales a la frecuencia.
# - Se usa en estudios de distribución de edades, temperaturas o ingresos.
#
# ###¿Quién los creó o desarrolló más a fondo?
# Los histogramas fueron desarrollados por Karl Pearson a finales del siglo XIX. Pearson fue uno de los fundadores de la estadística moderna y creó este gráfico como parte de sus investigaciones sobre la distribución de datos en poblaciones. Su trabajo se centró en desarrollar herramientas gráficas y matemáticas para analizar datos masivos, especialmente en biología y ciencias sociales.
#
# ![karl-pearson-1910-university-london (1).jpg](data:image/jpeg;base64,...)
# ###Aplicaciones prácticas en ingeniería
# 1. **Control de calidad en manufactura:**
#
# - Uso: Evaluar la distribución de dimensiones de piezas producidas en masa.
# - Ejemplo: Si fabricas tornillos, un histograma puede mostrar cuántos cumplen con las especificaciones de longitud (dentro del rango aceptable).
#
# 2. Análisis de tiempos de falla (ingeniería de confiabilidad):
#
# - Uso: Identificar patrones en el tiempo de vida útil de componentes.
# - Ejemplo: Un histograma puede mostrar cuántos dispositivos fallan después de 1, 2, o 5 años, ayudando a mejorar diseños o materiales.
#
# 3. Optimización de procesos:
#
# - Uso: Analizar el tiempo de producción en diferentes etapas.
# - Ejemplo: Un histograma del tiempo que toma ensamblar un producto puede revelar cuellos de botella.
#
# ##**Comparativas entre otros métodos**
# - Vs. Gráficos de barras: Los histogramas son para datos continuos, mientras que los gráficos de barras son para datos categóricos.
# - Vs. Diagramas de caja: Los histogramas muestran la forma de la distribución, mientras que los diagramas de caja resumen los datos mediante cuartiles y valores extremos.
#
# ---
# #**Diagrama de tallo y hoja**
# ###¿Qué son y para qué sirven?
# Es un gráfico que organiza los datos en forma de tallos (dígitos principales) y hojas (dígitos secundarios). Sirve para mostrar la distribución y mantener los valores originales de los datos.
#
# ![images (1) (1).png](data:image/png;base64,...)
# ###**Características**
# - Compacto y detallado.
# - Permite identificar la moda y el rango rápidamente.
# - Útil para conjuntos de datos pequeños o medianos.
#
# ###**Cómo se realizan y en qué casos**
# Divide los números en "tallos" (parte entera) y "hojas" (dígitos restantes).
# Agrúpalos en orden ascendente.
# Se usa para observar la forma de la distribución en datos numéricos pequeños, como resultados de pruebas.
#
# ###**¿Quién los creó o desarrolló más a fondo?
# El diagrama de tallo y hoja fue introducido por John Tukey en la década de 1970. Tukey fue pionero en el campo del análisis exploratorio de datos, una rama de la estadística que enfatiza la visualización y el entendimiento inicial de los datos antes de realizar análisis más profundos. Este método destaca por ser una herramienta visual rápida que no requiere tecnología avanzada para identificar patrones o tendencias.
#
# ![Screen_Shot_2021-02-10_at_8.36.04_AM_big (1).png](data:image/png;base64,...)
#
# ###**Aplicaciones prácticas en ingeniería
# 1. **Análisis de mediciones experimentales:**
#
# - Uso: Evaluar datos recolectados en pruebas de laboratorio o campo.
#
# - Ejemplo: En un ensayo de resistencia de materiales, este diagrama permite visualizar valores como 120 MPa, 122 MPa y 125 MPa, y notar agrupamientos o valores fuera de rango.
#
# 2. **Control de calidad para lotes pequeños:**
#
# - Uso: Analizar rápidamente pequeñas muestras de datos de producción.
# - Ejemplo: Verificar la uniformidad de medidas de 20 piezas de un lote inicial.
#
# 3. Detección de errores en series temporales:
#
# - Uso: Observar tendencias en mediciones de una misma variable a lo largo del tiempo.
# - Ejemplo: Seguimiento de temperaturas en pruebas de estrés térmico para componentes electrónicos.
#
# ###**Comparativas entre otros métodos**
# - Vs. Histogramas: El diagrama de tallo y hoja conserva los datos originales, mientras que el histograma agrupa los datos.
# - Vs. Diagramas de dispersión: El diagrama de tallo y hoja no muestra relaciones entre variables, pero es más directo para distribuciones simples.
#
# ---
# #**Diagrama de caja**
# ###**¿Qué son y para qué sirven?**
# Es un gráfico que resume un conjunto de datos mediante cinco valores clave: mínimo, primer cuartil, mediana, tercer cuartil y máximo. Sirve para identificar dispersión, simetría y valores atípicos.
#
# ![rsc-57753-5e853cd9be86f (1).png](data:image/png;base64,...)
# ###**Características**
# - Muestra la distribución de los datos en cuartiles.
# - Incluye "bigotes" para señalar el rango intercuartílico.
# - Resalta valores extremos o atípicos.
#
# ###**¿Cómo se realizan y en qué casos?**
# Calcula los cinco valores clave (mínimo, Q1, mediana, Q3, máximo).
# Dibuja un rectángulo que conecte Q1 y Q3, con una línea para la mediana.
# Añade líneas (bigotes) para indicar el rango, y marca valores atípicos.
# Útil en estudios de variabilidad como tiempos de espera o rendimiento.
#
# ###**¿Quién los creó o desarrolló más a fondo?**
# El diagrama de caja (o boxplot) también fue desarrollado por John Tukey como parte de su enfoque en el análisis exploratorio. Tukey buscaba herramientas que resumieran grandes cantidades de datos en un formato simple, permitiendo identificar valores atípicos y comprender la variabilidad de manera rápida.
#
# ###**Aplicaciones prácticas en ingeniería**
# 1. **Análisis de variabilidad en procesos:**
#
# - Uso: Comparar la variabilidad de diferentes líneas de producción.
# - Ejemplo: En una planta, se usan diagramas de caja para evaluar si dos máquinas producen piezas con la misma dispersión en dimensiones.
# Evaluación de rendimiento en sistemas:
#
# - Uso: Identificar el rango y valores atípicos en datos de eficiencia energética.
# - Ejemplo: Analizar el consumo de energía de 50 motores eléctricos y detectar motores con consumo inusualmente alto.
# Estudio de tolerancias en diseño mecánico:
#
# - Uso: Garantizar que los componentes fabricados cumplan con las especificaciones de diseño.
# - Ejemplo: Si el diámetro de un eje debe estar entre 10 y 10.5 mm, un diagrama de caja revela qué porcentaje de piezas cae dentro de ese rango y cuáles son defectuosas.
#
# ###**Comparativas entre otros métodos**
# - Vs. Histogramas: El diagrama de caja no muestra la forma de la distribución, pero es más efectivo para detectar valores atípicos.
# - Vs. Diagramas de tallo y hoja: El diagrama de caja es más útil para grandes conjuntos de datos donde el detalle no es tan relevante.
